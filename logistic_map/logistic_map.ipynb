# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
r = 4
a = 0.67
time = str(time.time()*10000)
time = int(time[10:13])
list = []
print(time)
for i in range(1, time):
    a = a*r*(1-a)
    list.append(a)
plot = plt.plot(list)
plot
# Out:
# 677
